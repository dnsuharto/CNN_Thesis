# %% [markdown]
# Import Library

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# Prepare Data

# %%
train_dir = '/content/drive/MyDrive/Latihan/training'
val_dir = '/content/drive/MyDrive/Latihan/validation'
target_size = (32,32)
classes = 4

train_datagen = ImageDataGenerator(rescale=1./255,
                                   #horizontal_flip=True,
                                   #vertical_flip=True,
                                   #rotation_range=45,
                                   #zoom_range=0.1,
                                   #validation_split=0.3
                                   )

val_datagen = ImageDataGenerator(rescale=1./255,
                                 #horizontal_flip=True,
                                  # vertical_flip=True,
                                   #rotation_range=90,
                                   #zoom_range=0.1,
                                 )

train_gen = train_datagen.flow_from_directory(train_dir,
                                              target_size=target_size,
                                              batch_size=32,
                                              color_mode='rgb',
                                              shuffle=True,
                                              class_mode='categorical',
                                              #subset='training'
                                              )

val_gen = train_datagen.flow_from_directory(val_dir,
                                            target_size=target_size,
                                            batch_size=32,
                                            color_mode='rgb',
                                            shuffle=False,
                                            class_mode='categorical',
                                            #subset='validation'
                                            )


#num_class = test_generator.num_classes
labels_train = train_gen.class_indices.keys()
labels_val = val_gen.class_indices.keys()
print(labels_train)
print(labels_val)
# Out:
# Found 3200 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
# dict_keys(['blight', 'gray', 'healthy', 'rust'])
# dict_keys(['blight', 'gray', 'healthy', 'rust'])

# %% [markdown]
# Create Model

# %%
#callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model = Sequential()
model.add(Conv2D(32,kernel_size=3,strides=1,activation='relu',
                 #padding='same',
                 input_shape=(32,32,3)))
model.add(MaxPooling2D(pool_size=(2,2),strides=1))

model.add(Conv2D(64,kernel_size=3,strides=1,activation='relu',
                 #padding='same'
                 ))
model.add(MaxPooling2D(pool_size=(2,2),strides=1))

#model.add(Conv2D(128,
                  #64,
 #                kernel_size=3,strides=1,activation='relu',
                 #padding='same'
#                 ))
#model.add(MaxPooling2D(pool_size=(2,2),strides=1))

#model.add(Conv2D(128,kernel_size=3,strides=1,activation='relu',padding='same'))
#model.add(MaxPooling2D(pool_size=(2,2),strides=1))

model.add(Flatten())
model.add(Dropout(0.5))#tes 1 0,5 #testing 2 menaikkan menjadi 0,6
#model.add(Dense(64,activation='relu'))
#model.add(Dense(256,activation='relu'))# testing 2
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(classes,activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 29, 29, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 27, 27, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 43264)             0
#
#  dropout (Dropout)           (None, 43264)             0
#
#  dense (Dense)               (None, 128)               5537920
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 5,565,828
# Trainable params: 5,565,828
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compile model

# %%
history = model.fit_generator(
    train_gen,epochs=50,validation_data=val_gen, 
    #callbacks=[callback]
)
# Out:
# <ipython-input-6-7d97c4944c00>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/50
# 100/100 [==============================] - 858s 9s/step - loss: 1.2168 - accuracy: 0.4141 - val_loss: 1.0276 - val_accuracy: 0.5138
# Epoch 2/50
# 100/100 [==============================] - 33s 328ms/step - loss: 0.8889 - accuracy: 0.6112 - val_loss: 0.7915 - val_accuracy: 0.6562
# Epoch 3/50
# 100/100 [==============================] - 32s 325ms/step - loss: 0.7407 - accuracy: 0.6853 - val_loss: 0.6352 - val_accuracy: 0.7625
# Epoch 4/50
# 100/100 [==============================] - 32s 317ms/step - loss: 0.6736 - accuracy: 0.7287 - val_loss: 0.8857 - val_accuracy: 0.6388
# Epoch 5/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.6017 - accuracy: 0.7544 - val_loss: 0.4325 - val_accuracy: 0.8587
# Epoch 6/50
# 100/100 [==============================] - 35s 350ms/step - loss: 0.5385 - accuracy: 0.7800 - val_loss: 0.3786 - val_accuracy: 0.8625
# Epoch 7/50
# 100/100 [==============================] - 32s 324ms/step - loss: 0.4778 - accuracy: 0.8091 - val_loss: 0.4733 - val_accuracy: 0.8125
# Epoch 8/50
# 100/100 [==============================] - 32s 320ms/step - loss: 0.4142 - accuracy: 0.8394 - val_loss: 0.2986 - val_accuracy: 0.8913
# Epoch 9/50
# 100/100 [==============================] - 34s 341ms/step - loss: 0.3107 - accuracy: 0.8813 - val_loss: 0.1938 - val_accuracy: 0.9475
# Epoch 10/50
# 100/100 [==============================] - 32s 316ms/step - loss: 0.3034 - accuracy: 0.8969 - val_loss: 0.3522 - val_accuracy: 0.8500
# Epoch 11/50
# 100/100 [==============================] - 32s 317ms/step - loss: 0.2244 - accuracy: 0.9212 - val_loss: 0.1525 - val_accuracy: 0.9600
# Epoch 12/50
# 100/100 [==============================] - 35s 352ms/step - loss: 0.2143 - accuracy: 0.9212 - val_loss: 0.1684 - val_accuracy: 0.9513
# Epoch 13/50
# 100/100 [==============================] - 32s 318ms/step - loss: 0.1859 - accuracy: 0.9381 - val_loss: 0.1255 - val_accuracy: 0.9725
# Epoch 14/50
# 100/100 [==============================] - 40s 404ms/step - loss: 0.1374 - accuracy: 0.9534 - val_loss: 0.1625 - val_accuracy: 0.9475
# Epoch 15/50
# 100/100 [==============================] - 32s 322ms/step - loss: 0.1712 - accuracy: 0.9347 - val_loss: 0.1059 - val_accuracy: 0.9700
# Epoch 16/50
# 100/100 [==============================] - 32s 324ms/step - loss: 0.1352 - accuracy: 0.9534 - val_loss: 0.2527 - val_accuracy: 0.9287
# Epoch 17/50
# 100/100 [==============================] - 32s 318ms/step - loss: 0.1659 - accuracy: 0.9444 - val_loss: 0.1664 - val_accuracy: 0.9538
# Epoch 18/50
# 100/100 [==============================] - 35s 349ms/step - loss: 0.1122 - accuracy: 0.9616 - val_loss: 0.0901 - val_accuracy: 0.9787
# Epoch 19/50
# 100/100 [==============================] - 32s 321ms/step - loss: 0.0653 - accuracy: 0.9791 - val_loss: 0.0846 - val_accuracy: 0.9800
# Epoch 20/50
# 100/100 [==============================] - 32s 317ms/step - loss: 0.0875 - accuracy: 0.9722 - val_loss: 0.1550 - val_accuracy: 0.9638
# Epoch 21/50
# 100/100 [==============================] - 32s 319ms/step - loss: 0.0672 - accuracy: 0.9787 - val_loss: 0.1647 - val_accuracy: 0.9613
# Epoch 22/50
# 100/100 [==============================] - 32s 321ms/step - loss: 0.0612 - accuracy: 0.9809 - val_loss: 0.0692 - val_accuracy: 0.9900
# Epoch 23/50
# 100/100 [==============================] - 35s 356ms/step - loss: 0.0524 - accuracy: 0.9828 - val_loss: 0.0803 - val_accuracy: 0.9862
# Epoch 24/50
# 100/100 [==============================] - 31s 312ms/step - loss: 0.0665 - accuracy: 0.9762 - val_loss: 0.0801 - val_accuracy: 0.9887
# Epoch 25/50
# 100/100 [==============================] - 32s 318ms/step - loss: 0.0685 - accuracy: 0.9797 - val_loss: 0.0903 - val_accuracy: 0.9862
# Epoch 26/50
# 100/100 [==============================] - 32s 318ms/step - loss: 0.0526 - accuracy: 0.9812 - val_loss: 0.0715 - val_accuracy: 0.9937
# Epoch 27/50
# 100/100 [==============================] - 32s 321ms/step - loss: 0.0222 - accuracy: 0.9922 - val_loss: 0.0634 - val_accuracy: 0.9925
# Epoch 28/50
# 100/100 [==============================] - 35s 348ms/step - loss: 0.0847 - accuracy: 0.9750 - val_loss: 0.0827 - val_accuracy: 0.9887
# Epoch 29/50
# 100/100 [==============================] - 32s 323ms/step - loss: 0.0753 - accuracy: 0.9747 - val_loss: 0.0990 - val_accuracy: 0.9775
# Epoch 30/50
# 100/100 [==============================] - 32s 323ms/step - loss: 0.0500 - accuracy: 0.9850 - val_loss: 0.0764 - val_accuracy: 0.9912
# Epoch 31/50
# 100/100 [==============================] - 33s 332ms/step - loss: 0.0469 - accuracy: 0.9847 - val_loss: 0.0838 - val_accuracy: 0.9887
# Epoch 32/50
# 100/100 [==============================] - 36s 361ms/step - loss: 0.0401 - accuracy: 0.9850 - val_loss: 0.0928 - val_accuracy: 0.9850
# Epoch 33/50
# 100/100 [==============================] - 32s 324ms/step - loss: 0.0179 - accuracy: 0.9953 - val_loss: 0.0719 - val_accuracy: 0.9925
# Epoch 34/50
# 100/100 [==============================] - 32s 323ms/step - loss: 0.0220 - accuracy: 0.9922 - val_loss: 0.0617 - val_accuracy: 0.9937
# Epoch 35/50
# 100/100 [==============================] - 33s 326ms/step - loss: 0.0133 - accuracy: 0.9941 - val_loss: 0.0781 - val_accuracy: 0.9925
# Epoch 36/50
# 100/100 [==============================] - 33s 326ms/step - loss: 0.0203 - accuracy: 0.9925 - val_loss: 0.0805 - val_accuracy: 0.9925
# Epoch 37/50
# 100/100 [==============================] - 32s 321ms/step - loss: 0.0369 - accuracy: 0.9878 - val_loss: 0.0688 - val_accuracy: 0.9937
# Epoch 38/50
# 100/100 [==============================] - 35s 349ms/step - loss: 0.0956 - accuracy: 0.9694 - val_loss: 0.0748 - val_accuracy: 0.9937
# Epoch 39/50
# 100/100 [==============================] - 32s 322ms/step - loss: 0.0214 - accuracy: 0.9934 - val_loss: 0.0702 - val_accuracy: 0.9937
# Epoch 40/50
# 100/100 [==============================] - 35s 348ms/step - loss: 0.0557 - accuracy: 0.9809 - val_loss: 0.0604 - val_accuracy: 0.9925
# Epoch 41/50
# 100/100 [==============================] - 32s 320ms/step - loss: 0.0481 - accuracy: 0.9869 - val_loss: 0.0512 - val_accuracy: 0.9937
# Epoch 42/50
# 100/100 [==============================] - 32s 321ms/step - loss: 0.0254 - accuracy: 0.9922 - val_loss: 0.0515 - val_accuracy: 0.9925
# Epoch 43/50
# 100/100 [==============================] - 32s 319ms/step - loss: 0.0160 - accuracy: 0.9959 - val_loss: 0.0800 - val_accuracy: 0.9937
# Epoch 44/50
# 100/100 [==============================] - 32s 318ms/step - loss: 0.0216 - accuracy: 0.9912 - val_loss: 0.0862 - val_accuracy: 0.9925
# Epoch 45/50
# 100/100 [==============================] - 34s 338ms/step - loss: 0.0402 - accuracy: 0.9891 - val_loss: 0.2225 - val_accuracy: 0.9513
# Epoch 46/50
# 100/100 [==============================] - 31s 314ms/step - loss: 0.1144 - accuracy: 0.9631 - val_loss: 0.0762 - val_accuracy: 0.9900
# Epoch 47/50
# 100/100 [==============================] - 32s 321ms/step - loss: 0.0132 - accuracy: 0.9969 - val_loss: 0.0785 - val_accuracy: 0.9937
# Epoch 48/50
# 100/100 [==============================] - 32s 321ms/step - loss: 0.0338 - accuracy: 0.9894 - val_loss: 0.0787 - val_accuracy: 0.9925
# Epoch 49/50
# 100/100 [==============================] - 37s 373ms/step - loss: 0.0170 - accuracy: 0.9956 - val_loss: 0.0733 - val_accuracy: 0.9912
# Epoch 50/50
# 100/100 [==============================] - 44s 437ms/step - loss: 0.0682 - accuracy: 0.9787 - val_loss: 0.0815 - val_accuracy: 0.9925

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
prediksi = model.predict(val_gen) #_generator
y_pred = np.argmax(prediksi, axis = 1)
labels_val = val_gen.class_indices.keys()
print(labels_train)
print(confusion_matrix(val_gen.classes,y_pred))
# Out:
# 25/25 [==============================] - 3s 93ms/step
# dict_keys(['blight', 'gray', 'healthy', 'rust'])
# [[199   1   0   0]
#  [  1 198   1   0]
#  [  2   0 198   0]
#  [  0   1   0 199]]

# %%
print(classification_report(val_gen.classes,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       200
#            1       0.99      0.99      0.99       200
#            2       0.99      0.99      0.99       200
#            3       1.00      0.99      1.00       200
#
#     accuracy                           0.99       800
#    macro avg       0.99      0.99      0.99       800
# weighted avg       0.99      0.99      0.99       800

# %%
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()
