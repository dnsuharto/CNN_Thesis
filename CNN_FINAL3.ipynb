# %% [markdown]
# <a href="https://colab.research.google.com/github/dnsuharto/CNN_Thesis/blob/main/CNN_FINAL3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Library

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# Prepare Data

# %%
train_dir = '/content/drive/MyDrive/Latihan/training'
val_dir = '/content/drive/MyDrive/Latihan/validation'
target_size = (32,32)
classes = 4

train_datagen = ImageDataGenerator(rescale=1./255,
                                   #horizontal_flip=True,
                                   #vertical_flip=True,
                                   #rotation_range=45,
                                   #zoom_range=0.1,
                                   #validation_split=0.3
                                   )

val_datagen = ImageDataGenerator(rescale=1./255,
                                 #horizontal_flip=True,
                                  # vertical_flip=True,
                                   #rotation_range=90,
                                   #zoom_range=0.1,
                                 )

train_gen = train_datagen.flow_from_directory(train_dir,
                                              target_size=target_size,
                                              batch_size=32,
                                              color_mode='rgb',
                                              shuffle=True,
                                              class_mode='categorical',
                                              #subset='training'
                                              )

val_gen = train_datagen.flow_from_directory(val_dir,
                                            target_size=target_size,
                                            batch_size=32,
                                            color_mode='rgb',
                                            shuffle=False,
                                            class_mode='categorical',
                                            #subset='validation'
                                            )


#num_class = test_generator.num_classes
labels_train = train_gen.class_indices.keys()
labels_val = val_gen.class_indices.keys()
print(labels_train)
print(labels_val)
# Out:
# Found 3200 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
# dict_keys(['blight', 'gray', 'healthy', 'rust'])
# dict_keys(['blight', 'gray', 'healthy', 'rust'])

# %% [markdown]
# Create Model

# %%
#callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model = Sequential()
model.add(Conv2D(32,kernel_size=3,strides=1,activation='relu',
                 #padding='same',
                 input_shape=(32,32,3)))
model.add(MaxPooling2D(pool_size=(2,2),strides=1))

model.add(Conv2D(64,kernel_size=3,strides=1,activation='relu',
                 #padding='same'
                 ))
model.add(MaxPooling2D(pool_size=(2,2),strides=1))

#model.add(Conv2D(128,
                  #64,
 #                kernel_size=3,strides=1,activation='relu',
                 #padding='same'
#                 ))
#model.add(MaxPooling2D(pool_size=(2,2),strides=1))

#model.add(Conv2D(128,kernel_size=3,strides=1,activation='relu',padding='same'))
#model.add(MaxPooling2D(pool_size=(2,2),strides=1))

model.add(Flatten())
model.add(Dropout(0.5))#tes 1 0,5 #testing 2 menaikkan menjadi 0,6
#model.add(Dense(64,activation='relu'))
#model.add(Dense(256,activation='relu'))# testing 2
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(classes,activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 30, 30, 32)        896
#
#  max_pooling2d_10 (MaxPoolin  (None, 29, 29, 32)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 27, 27, 64)        18496
#
#  max_pooling2d_11 (MaxPoolin  (None, 26, 26, 64)       0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 43264)             0
#
#  dropout_5 (Dropout)         (None, 43264)             0
#
#  dense_15 (Dense)            (None, 128)               5537920
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dense_17 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 5,565,828
# Trainable params: 5,565,828
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compile model

# %%
history = model.fit_generator(
    train_gen,epochs=50,validation_data=val_gen, 
    #callbacks=[callback]
)
# Out:
# <ipython-input-74-7d97c4944c00>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/50
#
# 100/100 [==============================] - 21s 210ms/step - loss: 0.0381 - accuracy: 0.9869 - val_loss: 0.1056 - val_accuracy: 0.9925
# Epoch 29/50
# 100/100 [==============================] - 23s 233ms/step - loss: 0.0981 - accuracy: 0.9697 - val_loss: 0.0965 - val_accuracy: 0.9862
# Epoch 30/50
# 100/100 [==============================] - 22s 218ms/step - loss: 0.0307 - accuracy: 0.9903 - val_loss: 0.0830 - val_accuracy: 0.9937
# Epoch 31/50
# 100/100 [==============================] - 21s 210ms/step - loss: 0.0249 - accuracy: 0.9900 - val_loss: 0.0850 - val_accuracy: 0.9925
# Epoch 32/50
# 100/100 [==============================] - 22s 217ms/step - loss: 0.0326 - accuracy: 0.9884 - val_loss: 0.1394 - val_accuracy: 0.9725
# Epoch 33/50
# 100/100 [==============================] - 22s 218ms/step - loss: 0.0551 - accuracy: 0.9841 - val_loss: 0.0780 - val_accuracy: 0.9950
# Epoch 34/50
# 100/100 [==============================] - 21s 209ms/step - loss: 0.0134 - accuracy: 0.9953 - val_loss: 0.0771 - val_accuracy: 0.9937
# Epoch 35/50
# 100/100 [==============================] - 22s 219ms/step - loss: 0.0251 - accuracy: 0.9916 - val_loss: 0.1209 - val_accuracy: 0.9762
# Epoch 36/50
# 100/100 [==============================] - 24s 235ms/step - loss: 0.0364 - accuracy: 0.9897 - val_loss: 0.0799 - val_accuracy: 0.9937
# Epoch 37/50
# 100/100 [==============================] - 23s 226ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0849 - val_accuracy: 0.9950
# Epoch 38/50
# 100/100 [==============================] - 21s 210ms/step - loss: 0.0040 - accuracy: 0.9984 - val_loss: 0.0786 - val_accuracy: 0.9950
# Epoch 39/50
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0209 - accuracy: 0.9925 - val_loss: 0.0969 - val_accuracy: 0.9912
# Epoch 40/50
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0595 - accuracy: 0.9812 - val_loss: 0.0878 - val_accuracy: 0.9925
# Epoch 41/50
# 100/100 [==============================] - 21s 210ms/step - loss: 0.0268 - accuracy: 0.9919 - val_loss: 0.1036 - val_accuracy: 0.9850
# Epoch 42/50
# 100/100 [==============================] - 22s 225ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 0.0795 - val_accuracy: 0.9950
# Epoch 43/50
# 100/100 [==============================] - 21s 206ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0870 - val_accuracy: 0.9962
# Epoch 44/50
# 100/100 [==============================] - 22s 221ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.0967 - val_accuracy: 0.9937
# Epoch 45/50
# 100/100 [==============================] - 22s 221ms/step - loss: 0.0539 - accuracy: 0.9825 - val_loss: 0.0983 - val_accuracy: 0.9862
# Epoch 46/50
# 100/100 [==============================] - 21s 213ms/step - loss: 0.0376 - accuracy: 0.9872 - val_loss: 0.0931 - val_accuracy: 0.9875
# Epoch 47/50
# 100/100 [==============================] - 21s 205ms/step - loss: 0.0725 - accuracy: 0.9800 - val_loss: 0.0856 - val_accuracy: 0.9887
# Epoch 48/50
# 100/100 [==============================] - 22s 218ms/step - loss: 0.0209 - accuracy: 0.9928 - val_loss: 0.0732 - val_accuracy: 0.9937
# Epoch 49/50
# 100/100 [==============================] - 21s 214ms/step - loss: 0.0185 - accuracy: 0.9934 - val_loss: 0.0985 - val_accuracy: 0.9912
# Epoch 50/50
# 100/100 [==============================] - 23s 228ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0819 - val_accuracy: 0.9950

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
prediksi = model.predict(val_gen) #_generator
y_pred = np.argmax(prediksi, axis = 1)
labels_val = val_gen.class_indices.keys()
print(labels_train)
print(confusion_matrix(val_gen.classes,y_pred))
# Out:
# 25/25 [==============================] - 2s 84ms/step
# dict_keys(['blight', 'gray', 'healthy', 'rust'])
# [[199   0   0   1]
#  [  0 199   1   0]
#  [  1   0 199   0]
#  [  0   1   0 199]]

# %%
print(classification_report(val_gen.classes,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       200
#            1       0.99      0.99      0.99       200
#            2       0.99      0.99      0.99       200
#            3       0.99      0.99      0.99       200
#
#     accuracy                           0.99       800
#    macro avg       0.99      0.99      0.99       800
# weighted avg       0.99      0.99      0.99       800

# %%
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()
